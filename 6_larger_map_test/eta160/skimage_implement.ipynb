# %%
#https://scikit-image.org/docs/dev/api/skimage.morphology.html#skimage.morphology.label

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import skimage.morphology
from skimage.morphology import label

gval = 3
nval = 1

#pure_bkg_pred = np.load("100_pure_bkg_allpred.npy")
#bkgpSig_pred = np.load(f"100_bkgp_g{gval}_n{nval}_allpred.npy")

pure_bkg_pred = np.load("diff_stepsize/500_pure_bkg_allpred_5step.npy")
bkgpSig_pred = np.load(f"diff_stepsize/500_bkgp_g{gval}_n{nval}_allpred_5step.npy")
bkgpSig_true = np.load(f"diff_stepsize/500_sampled_sig_g{gval}_n{nval}_allpred_5step.npy")

pathsig = '/afs/crc.nd.edu/user/t/tkim12/Work/CMB_ML/Data/Nside1024/test_img/'
sig_only = np.empty((0, 720, 720))
for evnts in range(3):
    temp2 = np.load(pathsig+"sig_larger/100_PHS_720sq_g1_Sig_onLSS_"+str(evnts+1)+".npy")
    sig_only = np.concatenate((sig_only,temp2))

sideval = int(np.sqrt(pure_bkg_pred.shape[1]))
reshaped_bkg = pure_bkg_pred.reshape((500,sideval,sideval))
reshaped_sig = bkgpSig_pred.reshape((500,sideval,sideval))

# %%
sideval
# Out:
# 127

# %%
clean_sig = (reshaped_sig > 0.9)# All exists in T/F  # could do "* reshaped_sig" for 
clean_bkg = (reshaped_bkg > 0.9)# All exists in T/F  # could do "* reshaped_sig" for

cleaned_sigs = []
cleaned_bkgs = []

true_sigcap = 0
fake_bkgcap = 0

for evnt in range(len(reshaped_sig)):
    
    clean_sig2 = label(clean_sig[evnt], background = 0, connectivity=2)
    clean_bkg2 = label(clean_bkg[evnt], background = 0, connectivity=2)
    
    sig2max = clean_sig2.max()
    bkg2max = clean_bkg2.max()
    
    subtract = 0
    clustering_val_threshold = 20
    
    for ii in range(1, sig2max+1):
        extact = clean_sig2[clean_sig2==ii]
        filtr = (clean_sig2!=ii)
        
        if len(extact) < clustering_val_threshold:
            clean_sig2 = filtr * clean_sig2
            subtract += 1
    
    subtractbkg = 0
    for jj in range(1, bkg2max+1):
        extact = clean_bkg2[clean_bkg2==jj]
        filtr = (clean_bkg2!=jj)
        
        if len(extact) < clustering_val_threshold:
            clean_bkg2 = filtr * clean_bkg2
            subtractbkg += 1
    
    cleaned_sigs.append(clean_sig2)
    cleaned_bkgs.append(clean_bkg2)
    
    sig_candid = sig2max-subtract
    bkg_fake = bkg2max-subtractbkg
    
    print(f"Event {evnt+1} : Clutered PHS candidate in window = {sig_candid} with {bkg_fake} fake")
    true_sigcap += sig_candid - bkg_fake
    fake_bkgcap += bkg_fake

cleaned_sigs = np.array(cleaned_sigs)
cleaned_bkgs = np.array(cleaned_bkgs)
# Out:
# Event 1 : Clutered PHS candidate in window = 1 with 0 fake
# Event 2 : Clutered PHS candidate in window = 1 with 0 fake
# Event 3 : Clutered PHS candidate in window = 1 with 0 fake
# Event 4 : Clutered PHS candidate in window = 1 with 0 fake
# Event 5 : Clutered PHS candidate in window = 1 with 0 fake
# Event 6 : Clutered PHS candidate in window = 1 with 0 fake
# Event 7 : Clutered PHS candidate in window = 1 with 0 fake
# Event 8 : Clutered PHS candidate in window = 1 with 0 fake
# Event 9 : Clutered PHS candidate in window = 1 with 0 fake
# Event 10 : Clutered PHS candidate in window = 1 with 0 fake
# Event 11 : Clutered PHS candidate in window = 1 with 0 fake
# Event 12 : Clutered PHS candidate in window = 1 with 0 fake
# Event 13 : Clutered PHS candidate in window = 2 with 1 fake
# Event 14 : Clutered PHS candidate in window = 1 with 0 fake
# Event 15 : Clutered PHS candidate in window = 1 with 0 fake
# Event 16 : Clutered PHS candidate in window = 1 with 0 fake
# Event 17 : Clutered PHS candidate in window = 1 with 0 fake
# Event 18 : Clutered PHS candidate in window = 1 with 0 fake
# Event 19 : Clutered PHS candidate in window = 1 with 0 fake
# Event 20 : Clutered PHS candidate in window = 1 with 0 fake
# Event 21 : Clutered PHS candidate in window = 1 with 0 fake
# Event 22 : Clutered PHS candidate in window = 2 with 1 fake
# Event 23 : Clutered PHS candidate in window = 1 with 0 fake
# Event 24 : Clutered PHS candidate in window = 1 with 0 fake
# Event 25 : Clutered PHS candidate in window = 1 with 0 fake
# Event 26 : Clutered PHS candidate in window = 2 with 1 fake
# Event 27 : Clutered PHS candidate in window = 1 with 0 fake
# Event 28 : Clutered PHS candidate in window = 1 with 0 fake
# Event 29 : Clutered PHS candidate in window = 1 with 0 fake
# Event 30 : Clutered PHS candidate in window = 1 with 0 fake
# Event 31 : Clutered PHS candidate in window = 1 with 0 fake
# Event 32 : Clutered PHS candidate in window = 1 with 0 fake
# Event 33 : Clutered PHS candidate in window = 1 with 0 fake
# Event 34 : Clutered PHS candidate in window = 1 with 0 fake
# Event 35 : Clutered PHS candidate in window = 1 with 0 fake
# Event 36 : Clutered PHS candidate in window = 1 with 0 fake
# Event 37 : Clutered PHS candidate in window = 1 with 0 fake
# Event 38 : Clutered PHS candidate in window = 1 with 0 fake
# Event 39 : Clutered PHS candidate in window = 1 with 0 fake
# Event 40 : Clutered PHS candidate in window = 1 with 0 fake
# Event 41 : Clutered PHS candidate in window = 1 with 0 fake
# Event 42 : Clutered PHS candidate in window = 2 with 1 fake
# Event 43 : Clutered PHS candidate in window = 1 with 0 fake
# Event 44 : Clutered PHS candidate in window = 1 with 0 fake
# Event 45 : Clutered PHS candidate in window = 1 with 0 fake
# Event 46 : Clutered PHS candidate in window = 1 with 0 fake
# Event 47 : Clutered PHS candidate in window = 1 with 0 fake
# Event 48 : Clutered PHS candidate in window = 1 with 0 fake
# Event 49 : Clutered PHS candidate in window = 1 with 0 fake
# Event 50 : Clutered PHS candidate in window = 1 with 0 fake
# Event 51 : Clutered PHS candidate in window = 1 with 0 fake
# Event 52 : Clutered PHS candidate in window = 1 with 0 fake
# Event 53 : Clutered PHS candidate in window = 1 with 0 fake
# Event 54 : Clutered PHS candidate in window = 2 with 1 fake
# Event 55 : Clutered PHS candidate in window = 1 with 0 fake
# Event 56 : Clutered PHS candidate in window = 1 with 0 fake
# Event 57 : Clutered PHS candidate in window = 1 with 0 fake
# Event 58 : Clutered PHS candidate in window = 2 with 1 fake
# Event 59 : Clutered PHS candidate in window = 1 with 0 fake
# Event 60 : Clutered PHS candidate in window = 1 with 0 fake
# Event 61 : Clutered PHS candidate in window = 1 with 0 fake
# Event 62 : Clutered PHS candidate in window = 1 with 0 fake
# Event 63 : Clutered PHS candidate in window = 1 with 0 fake
# Event 64 : Clutered PHS candidate in window = 1 with 0 fake
# Event 65 : Clutered PHS candidate in window = 1 with 0 fake
# Event 66 : Clutered PHS candidate in window = 1 with 0 fake
# Event 67 : Clutered PHS candidate in window = 1 with 0 fake
# Event 68 : Clutered PHS candidate in window = 1 with 0 fake
# Event 69 : Clutered PHS candidate in window = 1 with 0 fake
# Event 70 : Clutered PHS candidate in window = 1 with 0 fake
# Event 71 : Clutered PHS candidate in window = 1 with 0 fake
# Event 72 : Clutered PHS candidate in window = 1 with 0 fake
# Event 73 : Clutered PHS candidate in window = 1 with 0 fake
# Event 74 : Clutered PHS candidate in window = 2 with 1 fake
# Event 75 : Clutered PHS candidate in window = 1 with 0 fake
# Event 76 : Clutered PHS candidate in window = 1 with 0 fake
# Event 77 : Clutered PHS candidate in window = 1 with 0 fake
# Event 78 : Clutered PHS candidate in window = 1 with 0 fake
# Event 79 : Clutered PHS candidate in window = 1 with 0 fake
# Event 80 : Clutered PHS candidate in window = 1 with 0 fake
# Event 81 : Clutered PHS candidate in window = 2 with 1 fake
# Event 82 : Clutered PHS candidate in window = 2 with 1 fake
# Event 83 : Clutered PHS candidate in window = 1 with 0 fake
# Event 84 : Clutered PHS candidate in window = 1 with 0 fake
# Event 85 : Clutered PHS candidate in window = 1 with 0 fake
# Event 86 : Clutered PHS candidate in window = 1 with 0 fake
# Event 87 : Clutered PHS candidate in window = 1 with 0 fake
# Event 88 : Clutered PHS candidate in window = 1 with 0 fake
# Event 89 : Clutered PHS candidate in window = 1 with 0 fake
# Event 90 : Clutered PHS candidate in window = 1 with 0 fake
# Event 91 : Clutered PHS candidate in window = 1 with 0 fake
# Event 92 : Clutered PHS candidate in window = 1 with 0 fake
# Event 93 : Clutered PHS candidate in window = 1 with 0 fake
# Event 94 : Clutered PHS candidate in window = 1 with 0 fake
# Event 95 : Clutered PHS candidate in window = 1 with 0 fake
# Event 96 : Clutered PHS candidate in window = 1 with 0 fake
# Event 97 : Clutered PHS candidate in window = 1 with 0 fake
# Event 98 : Clutered PHS candidate in window = 1 with 0 fake
# Event 99 : Clutered PHS candidate in window = 1 with 0 fake
# Event 100 : Clutered PHS candidate in window = 1 with 0 fake
# Event 101 : Clutered PHS candidate in window = 1 with 0 fake
# Event 102 : Clutered PHS candidate in window = 1 with 0 fake
# Event 103 : Clutered PHS candidate in window = 1 with 0 fake
# Event 104 : Clutered PHS candidate in window = 1 with 0 fake
# Event 105 : Clutered PHS candidate in window = 1 with 0 fake
# Event 106 : Clutered PHS candidate in window = 1 with 0 fake
# Event 107 : Clutered PHS candidate in window = 1 with 0 fake
# Event 108 : Clutered PHS candidate in window = 1 with 0 fake
# Event 109 : Clutered PHS candidate in window = 1 with 0 fake
# Event 110 : Clutered PHS candidate in window = 1 with 0 fake
# Event 111 : Clutered PHS candidate in window = 1 with 0 fake
# Event 112 : Clutered PHS candidate in window = 1 with 0 fake
# Event 113 : Clutered PHS candidate in window = 1 with 0 fake
# Event 114 : Clutered PHS candidate in window = 1 with 0 fake
# Event 115 : Clutered PHS candidate in window = 1 with 0 fake
# Event 116 : Clutered PHS candidate in window = 1 with 0 fake
# Event 117 : Clutered PHS candidate in window = 1 with 0 fake
# Event 118 : Clutered PHS candidate in window = 1 with 0 fake
# Event 119 : Clutered PHS candidate in window = 2 with 1 fake
# Event 120 : Clutered PHS candidate in window = 1 with 0 fake
# Event 121 : Clutered PHS candidate in window = 1 with 0 fake
# Event 122 : Clutered PHS candidate in window = 1 with 0 fake
# Event 123 : Clutered PHS candidate in window = 1 with 0 fake
# Event 124 : Clutered PHS candidate in window = 1 with 0 fake
# Event 125 : Clutered PHS candidate in window = 1 with 0 fake
# Event 126 : Clutered PHS candidate in window = 1 with 0 fake
# Event 127 : Clutered PHS candidate in window = 1 with 0 fake
# Event 128 : Clutered PHS candidate in window = 1 with 0 fake
# Event 129 : Clutered PHS candidate in window = 1 with 0 fake
# Event 130 : Clutered PHS candidate in window = 1 with 0 fake
# Event 131 : Clutered PHS candidate in window = 1 with 0 fake
# Event 132 : Clutered PHS candidate in window = 1 with 0 fake
# Event 133 : Clutered PHS candidate in window = 1 with 0 fake
# Event 134 : Clutered PHS candidate in window = 1 with 0 fake
# Event 135 : Clutered PHS candidate in window = 1 with 0 fake
# Event 136 : Clutered PHS candidate in window = 1 with 0 fake
# Event 137 : Clutered PHS candidate in window = 1 with 0 fake
# Event 138 : Clutered PHS candidate in window = 1 with 0 fake
# Event 139 : Clutered PHS candidate in window = 1 with 0 fake
# Event 140 : Clutered PHS candidate in window = 0 with 0 fake
# Event 141 : Clutered PHS candidate in window = 1 with 0 fake
# Event 142 : Clutered PHS candidate in window = 1 with 0 fake
# Event 143 : Clutered PHS candidate in window = 1 with 0 fake
# Event 144 : Clutered PHS candidate in window = 1 with 0 fake
# Event 145 : Clutered PHS candidate in window = 1 with 0 fake
# Event 146 : Clutered PHS candidate in window = 1 with 0 fake
# Event 147 : Clutered PHS candidate in window = 1 with 0 fake
# Event 148 : Clutered PHS candidate in window = 1 with 0 fake
# Event 149 : Clutered PHS candidate in window = 1 with 0 fake
# Event 150 : Clutered PHS candidate in window = 1 with 0 fake
# Event 151 : Clutered PHS candidate in window = 1 with 0 fake
# Event 152 : Clutered PHS candidate in window = 2 with 1 fake
# Event 153 : Clutered PHS candidate in window = 1 with 0 fake
# Event 154 : Clutered PHS candidate in window = 1 with 0 fake
# Event 155 : Clutered PHS candidate in window = 1 with 0 fake
# Event 156 : Clutered PHS candidate in window = 1 with 0 fake
# Event 157 : Clutered PHS candidate in window = 1 with 0 fake
# Event 158 : Clutered PHS candidate in window = 1 with 0 fake
# Event 159 : Clutered PHS candidate in window = 1 with 0 fake
# Event 160 : Clutered PHS candidate in window = 1 with 0 fake
# Event 161 : Clutered PHS candidate in window = 1 with 0 fake
# Event 162 : Clutered PHS candidate in window = 2 with 1 fake
# Event 163 : Clutered PHS candidate in window = 1 with 0 fake
# Event 164 : Clutered PHS candidate in window = 1 with 0 fake
# Event 165 : Clutered PHS candidate in window = 0 with 0 fake
# Event 166 : Clutered PHS candidate in window = 1 with 0 fake
# Event 167 : Clutered PHS candidate in window = 2 with 1 fake
# Event 168 : Clutered PHS candidate in window = 1 with 0 fake
# Event 169 : Clutered PHS candidate in window = 1 with 0 fake
# Event 170 : Clutered PHS candidate in window = 1 with 0 fake
# Event 171 : Clutered PHS candidate in window = 1 with 0 fake
# Event 172 : Clutered PHS candidate in window = 1 with 0 fake
# Event 173 : Clutered PHS candidate in window = 1 with 0 fake
# Event 174 : Clutered PHS candidate in window = 1 with 0 fake
# Event 175 : Clutered PHS candidate in window = 1 with 0 fake
# Event 176 : Clutered PHS candidate in window = 1 with 0 fake
# Event 177 : Clutered PHS candidate in window = 1 with 0 fake
# Event 178 : Clutered PHS candidate in window = 1 with 0 fake
# Event 179 : Clutered PHS candidate in window = 1 with 0 fake
# Event 180 : Clutered PHS candidate in window = 1 with 0 fake
# Event 181 : Clutered PHS candidate in window = 1 with 0 fake
# Event 182 : Clutered PHS candidate in window = 1 with 0 fake
# Event 183 : Clutered PHS candidate in window = 1 with 0 fake
# Event 184 : Clutered PHS candidate in window = 2 with 1 fake
# Event 185 : Clutered PHS candidate in window = 1 with 0 fake
# Event 186 : Clutered PHS candidate in window = 1 with 0 fake
# Event 187 : Clutered PHS candidate in window = 1 with 0 fake
# Event 188 : Clutered PHS candidate in window = 1 with 0 fake
# Event 189 : Clutered PHS candidate in window = 1 with 0 fake
# Event 190 : Clutered PHS candidate in window = 1 with 0 fake
# Event 191 : Clutered PHS candidate in window = 1 with 0 fake
# Event 192 : Clutered PHS candidate in window = 2 with 1 fake
# Event 193 : Clutered PHS candidate in window = 1 with 0 fake
# Event 194 : Clutered PHS candidate in window = 1 with 0 fake
# Event 195 : Clutered PHS candidate in window = 2 with 1 fake
# Event 196 : Clutered PHS candidate in window = 1 with 0 fake
# Event 197 : Clutered PHS candidate in window = 1 with 0 fake
# Event 198 : Clutered PHS candidate in window = 1 with 0 fake
# Event 199 : Clutered PHS candidate in window = 1 with 0 fake
# Event 200 : Clutered PHS candidate in window = 1 with 0 fake
# Event 201 : Clutered PHS candidate in window = 2 with 1 fake
# Event 202 : Clutered PHS candidate in window = 1 with 0 fake
# Event 203 : Clutered PHS candidate in window = 1 with 0 fake
# Event 204 : Clutered PHS candidate in window = 1 with 0 fake
# Event 205 : Clutered PHS candidate in window = 1 with 0 fake
# Event 206 : Clutered PHS candidate in window = 1 with 0 fake
# Event 207 : Clutered PHS candidate in window = 2 with 1 fake
# Event 208 : Clutered PHS candidate in window = 1 with 0 fake
# Event 209 : Clutered PHS candidate in window = 1 with 0 fake
# Event 210 : Clutered PHS candidate in window = 1 with 0 fake
# Event 211 : Clutered PHS candidate in window = 1 with 0 fake
# Event 212 : Clutered PHS candidate in window = 1 with 0 fake
# Event 213 : Clutered PHS candidate in window = 1 with 0 fake
# Event 214 : Clutered PHS candidate in window = 1 with 0 fake
# Event 215 : Clutered PHS candidate in window = 1 with 0 fake
# Event 216 : Clutered PHS candidate in window = 1 with 0 fake
# Event 217 : Clutered PHS candidate in window = 1 with 0 fake
# Event 218 : Clutered PHS candidate in window = 1 with 0 fake
# Event 219 : Clutered PHS candidate in window = 1 with 0 fake
# Event 220 : Clutered PHS candidate in window = 1 with 0 fake
# Event 221 : Clutered PHS candidate in window = 1 with 0 fake
# Event 222 : Clutered PHS candidate in window = 1 with 0 fake
# Event 223 : Clutered PHS candidate in window = 1 with 0 fake
# Event 224 : Clutered PHS candidate in window = 1 with 0 fake
# Event 225 : Clutered PHS candidate in window = 1 with 0 fake
# Event 226 : Clutered PHS candidate in window = 1 with 0 fake
# Event 227 : Clutered PHS candidate in window = 1 with 0 fake
# Event 228 : Clutered PHS candidate in window = 2 with 1 fake
# Event 229 : Clutered PHS candidate in window = 1 with 0 fake
# Event 230 : Clutered PHS candidate in window = 1 with 0 fake
# Event 231 : Clutered PHS candidate in window = 1 with 0 fake
# Event 232 : Clutered PHS candidate in window = 1 with 0 fake
# Event 233 : Clutered PHS candidate in window = 1 with 0 fake
# Event 234 : Clutered PHS candidate in window = 1 with 0 fake
# Event 235 : Clutered PHS candidate in window = 1 with 0 fake
# Event 236 : Clutered PHS candidate in window = 2 with 1 fake
# Event 237 : Clutered PHS candidate in window = 1 with 0 fake
# Event 238 : Clutered PHS candidate in window = 1 with 0 fake
# Event 239 : Clutered PHS candidate in window = 1 with 0 fake
# Event 240 : Clutered PHS candidate in window = 1 with 0 fake
# Event 241 : Clutered PHS candidate in window = 1 with 0 fake
# Event 242 : Clutered PHS candidate in window = 1 with 0 fake
# Event 243 : Clutered PHS candidate in window = 1 with 0 fake
# Event 244 : Clutered PHS candidate in window = 1 with 0 fake
# Event 245 : Clutered PHS candidate in window = 1 with 0 fake
# Event 246 : Clutered PHS candidate in window = 1 with 0 fake
# Event 247 : Clutered PHS candidate in window = 1 with 0 fake
# Event 248 : Clutered PHS candidate in window = 1 with 0 fake
# Event 249 : Clutered PHS candidate in window = 1 with 0 fake
# Event 250 : Clutered PHS candidate in window = 1 with 0 fake
# Event 251 : Clutered PHS candidate in window = 1 with 0 fake
# Event 252 : Clutered PHS candidate in window = 1 with 0 fake
# Event 253 : Clutered PHS candidate in window = 1 with 0 fake
# Event 254 : Clutered PHS candidate in window = 1 with 0 fake
# Event 255 : Clutered PHS candidate in window = 1 with 0 fake
# Event 256 : Clutered PHS candidate in window = 1 with 0 fake
# Event 257 : Clutered PHS candidate in window = 1 with 0 fake
# Event 258 : Clutered PHS candidate in window = 1 with 0 fake
# Event 259 : Clutered PHS candidate in window = 1 with 0 fake
# Event 260 : Clutered PHS candidate in window = 1 with 0 fake
# Event 261 : Clutered PHS candidate in window = 1 with 0 fake
# Event 262 : Clutered PHS candidate in window = 1 with 0 fake
# Event 263 : Clutered PHS candidate in window = 1 with 0 fake
# Event 264 : Clutered PHS candidate in window = 1 with 0 fake
# Event 265 : Clutered PHS candidate in window = 1 with 0 fake
# Event 266 : Clutered PHS candidate in window = 1 with 0 fake
# Event 267 : Clutered PHS candidate in window = 1 with 0 fake
# Event 268 : Clutered PHS candidate in window = 1 with 0 fake
# Event 269 : Clutered PHS candidate in window = 1 with 0 fake
# Event 270 : Clutered PHS candidate in window = 1 with 0 fake
# Event 271 : Clutered PHS candidate in window = 1 with 0 fake
# Event 272 : Clutered PHS candidate in window = 1 with 0 fake
# Event 273 : Clutered PHS candidate in window = 1 with 0 fake
# Event 274 : Clutered PHS candidate in window = 1 with 0 fake
# Event 275 : Clutered PHS candidate in window = 1 with 0 fake
# Event 276 : Clutered PHS candidate in window = 1 with 0 fake
# Event 277 : Clutered PHS candidate in window = 1 with 0 fake
# Event 278 : Clutered PHS candidate in window = 1 with 0 fake
# Event 279 : Clutered PHS candidate in window = 1 with 0 fake
# Event 280 : Clutered PHS candidate in window = 1 with 0 fake
# Event 281 : Clutered PHS candidate in window = 1 with 0 fake
# Event 282 : Clutered PHS candidate in window = 1 with 0 fake
# Event 283 : Clutered PHS candidate in window = 1 with 0 fake
# Event 284 : Clutered PHS candidate in window = 1 with 0 fake
# Event 285 : Clutered PHS candidate in window = 1 with 0 fake
# Event 286 : Clutered PHS candidate in window = 1 with 0 fake
# Event 287 : Clutered PHS candidate in window = 1 with 0 fake
# Event 288 : Clutered PHS candidate in window = 1 with 0 fake
# Event 289 : Clutered PHS candidate in window = 1 with 0 fake
# Event 290 : Clutered PHS candidate in window = 1 with 0 fake
# Event 291 : Clutered PHS candidate in window = 1 with 0 fake
# Event 292 : Clutered PHS candidate in window = 1 with 0 fake
# Event 293 : Clutered PHS candidate in window = 1 with 0 fake
# Event 294 : Clutered PHS candidate in window = 1 with 0 fake
# Event 295 : Clutered PHS candidate in window = 1 with 0 fake
# Event 296 : Clutered PHS candidate in window = 1 with 0 fake
# Event 297 : Clutered PHS candidate in window = 1 with 0 fake
# Event 298 : Clutered PHS candidate in window = 1 with 0 fake
# Event 299 : Clutered PHS candidate in window = 1 with 0 fake
# Event 300 : Clutered PHS candidate in window = 1 with 0 fake
# Event 301 : Clutered PHS candidate in window = 1 with 0 fake
# Event 302 : Clutered PHS candidate in window = 1 with 0 fake
# Event 303 : Clutered PHS candidate in window = 1 with 0 fake
# Event 304 : Clutered PHS candidate in window = 1 with 0 fake
# Event 305 : Clutered PHS candidate in window = 1 with 0 fake
# Event 306 : Clutered PHS candidate in window = 1 with 0 fake
# Event 307 : Clutered PHS candidate in window = 1 with 0 fake
# Event 308 : Clutered PHS candidate in window = 1 with 0 fake
# Event 309 : Clutered PHS candidate in window = 1 with 0 fake
# Event 310 : Clutered PHS candidate in window = 1 with 0 fake
# Event 311 : Clutered PHS candidate in window = 1 with 0 fake
# Event 312 : Clutered PHS candidate in window = 1 with 0 fake
# Event 313 : Clutered PHS candidate in window = 1 with 0 fake
# Event 314 : Clutered PHS candidate in window = 1 with 0 fake
# Event 315 : Clutered PHS candidate in window = 1 with 0 fake
# Event 316 : Clutered PHS candidate in window = 1 with 0 fake
# Event 317 : Clutered PHS candidate in window = 1 with 0 fake
# Event 318 : Clutered PHS candidate in window = 1 with 0 fake
# Event 319 : Clutered PHS candidate in window = 1 with 0 fake
# Event 320 : Clutered PHS candidate in window = 1 with 0 fake
# Event 321 : Clutered PHS candidate in window = 1 with 0 fake
# Event 322 : Clutered PHS candidate in window = 1 with 0 fake
# Event 323 : Clutered PHS candidate in window = 1 with 0 fake
# Event 324 : Clutered PHS candidate in window = 1 with 0 fake
# Event 325 : Clutered PHS candidate in window = 1 with 0 fake
# Event 326 : Clutered PHS candidate in window = 1 with 0 fake
# Event 327 : Clutered PHS candidate in window = 1 with 0 fake
# Event 328 : Clutered PHS candidate in window = 1 with 0 fake
# Event 329 : Clutered PHS candidate in window = 1 with 0 fake
# Event 330 : Clutered PHS candidate in window = 1 with 0 fake
# Event 331 : Clutered PHS candidate in window = 1 with 0 fake
# Event 332 : Clutered PHS candidate in window = 1 with 0 fake
# Event 333 : Clutered PHS candidate in window = 1 with 0 fake
# Event 334 : Clutered PHS candidate in window = 1 with 0 fake
# Event 335 : Clutered PHS candidate in window = 1 with 0 fake
# Event 336 : Clutered PHS candidate in window = 1 with 0 fake
# Event 337 : Clutered PHS candidate in window = 1 with 0 fake
# Event 338 : Clutered PHS candidate in window = 1 with 0 fake
# Event 339 : Clutered PHS candidate in window = 1 with 0 fake
# Event 340 : Clutered PHS candidate in window = 1 with 0 fake
# Event 341 : Clutered PHS candidate in window = 1 with 0 fake
# Event 342 : Clutered PHS candidate in window = 1 with 0 fake
# Event 343 : Clutered PHS candidate in window = 1 with 0 fake
# Event 344 : Clutered PHS candidate in window = 1 with 0 fake
# Event 345 : Clutered PHS candidate in window = 1 with 0 fake
# Event 346 : Clutered PHS candidate in window = 1 with 0 fake
# Event 347 : Clutered PHS candidate in window = 1 with 0 fake
# Event 348 : Clutered PHS candidate in window = 2 with 1 fake
# Event 349 : Clutered PHS candidate in window = 1 with 0 fake
# Event 350 : Clutered PHS candidate in window = 1 with 0 fake
# Event 351 : Clutered PHS candidate in window = 1 with 0 fake
# Event 352 : Clutered PHS candidate in window = 1 with 0 fake
# Event 353 : Clutered PHS candidate in window = 1 with 0 fake
# Event 354 : Clutered PHS candidate in window = 1 with 0 fake
# Event 355 : Clutered PHS candidate in window = 1 with 0 fake
# Event 356 : Clutered PHS candidate in window = 1 with 0 fake
# Event 357 : Clutered PHS candidate in window = 1 with 0 fake
# Event 358 : Clutered PHS candidate in window = 2 with 1 fake
# Event 359 : Clutered PHS candidate in window = 1 with 0 fake
# Event 360 : Clutered PHS candidate in window = 1 with 0 fake
# Event 361 : Clutered PHS candidate in window = 1 with 1 fake
# Event 362 : Clutered PHS candidate in window = 1 with 0 fake
# Event 363 : Clutered PHS candidate in window = 1 with 0 fake
# Event 364 : Clutered PHS candidate in window = 1 with 0 fake
# Event 365 : Clutered PHS candidate in window = 1 with 0 fake
# Event 366 : Clutered PHS candidate in window = 1 with 0 fake
# Event 367 : Clutered PHS candidate in window = 1 with 0 fake
# Event 368 : Clutered PHS candidate in window = 1 with 0 fake
# Event 369 : Clutered PHS candidate in window = 1 with 0 fake
# Event 370 : Clutered PHS candidate in window = 1 with 0 fake
# Event 371 : Clutered PHS candidate in window = 1 with 0 fake
# Event 372 : Clutered PHS candidate in window = 1 with 0 fake
# Event 373 : Clutered PHS candidate in window = 1 with 0 fake
# Event 374 : Clutered PHS candidate in window = 1 with 0 fake
# Event 375 : Clutered PHS candidate in window = 1 with 0 fake
# Event 376 : Clutered PHS candidate in window = 1 with 0 fake
# Event 377 : Clutered PHS candidate in window = 1 with 0 fake
# Event 378 : Clutered PHS candidate in window = 1 with 0 fake
# Event 379 : Clutered PHS candidate in window = 1 with 0 fake
# Event 380 : Clutered PHS candidate in window = 1 with 0 fake
# Event 381 : Clutered PHS candidate in window = 1 with 0 fake
# Event 382 : Clutered PHS candidate in window = 1 with 0 fake
# Event 383 : Clutered PHS candidate in window = 1 with 0 fake
# Event 384 : Clutered PHS candidate in window = 1 with 0 fake
# Event 385 : Clutered PHS candidate in window = 1 with 0 fake
# Event 386 : Clutered PHS candidate in window = 1 with 0 fake
# Event 387 : Clutered PHS candidate in window = 2 with 1 fake
# Event 388 : Clutered PHS candidate in window = 2 with 1 fake
# Event 389 : Clutered PHS candidate in window = 2 with 1 fake
# Event 390 : Clutered PHS candidate in window = 1 with 0 fake
# Event 391 : Clutered PHS candidate in window = 1 with 0 fake
# Event 392 : Clutered PHS candidate in window = 1 with 0 fake
# Event 393 : Clutered PHS candidate in window = 1 with 0 fake
# Event 394 : Clutered PHS candidate in window = 1 with 0 fake
# Event 395 : Clutered PHS candidate in window = 1 with 0 fake
# Event 396 : Clutered PHS candidate in window = 1 with 0 fake
# Event 397 : Clutered PHS candidate in window = 1 with 0 fake
# Event 398 : Clutered PHS candidate in window = 1 with 0 fake
# Event 399 : Clutered PHS candidate in window = 1 with 0 fake
# Event 400 : Clutered PHS candidate in window = 1 with 0 fake
# Event 401 : Clutered PHS candidate in window = 2 with 1 fake
# Event 402 : Clutered PHS candidate in window = 2 with 1 fake
# Event 403 : Clutered PHS candidate in window = 1 with 0 fake
# Event 404 : Clutered PHS candidate in window = 1 with 0 fake
# Event 405 : Clutered PHS candidate in window = 1 with 0 fake
# Event 406 : Clutered PHS candidate in window = 1 with 0 fake
# Event 407 : Clutered PHS candidate in window = 1 with 0 fake
# Event 408 : Clutered PHS candidate in window = 1 with 0 fake
# Event 409 : Clutered PHS candidate in window = 1 with 0 fake
# Event 410 : Clutered PHS candidate in window = 1 with 0 fake
# Event 411 : Clutered PHS candidate in window = 1 with 0 fake
# Event 412 : Clutered PHS candidate in window = 1 with 0 fake
# Event 413 : Clutered PHS candidate in window = 1 with 0 fake
# Event 414 : Clutered PHS candidate in window = 1 with 0 fake
# Event 415 : Clutered PHS candidate in window = 1 with 0 fake
# Event 416 : Clutered PHS candidate in window = 1 with 0 fake
# Event 417 : Clutered PHS candidate in window = 1 with 0 fake
# Event 418 : Clutered PHS candidate in window = 1 with 0 fake
# Event 419 : Clutered PHS candidate in window = 1 with 0 fake
# Event 420 : Clutered PHS candidate in window = 1 with 0 fake
# Event 421 : Clutered PHS candidate in window = 1 with 0 fake
# Event 422 : Clutered PHS candidate in window = 1 with 0 fake
# Event 423 : Clutered PHS candidate in window = 1 with 0 fake
# Event 424 : Clutered PHS candidate in window = 1 with 0 fake
# Event 425 : Clutered PHS candidate in window = 1 with 0 fake
# Event 426 : Clutered PHS candidate in window = 1 with 0 fake
# Event 427 : Clutered PHS candidate in window = 2 with 1 fake
# Event 428 : Clutered PHS candidate in window = 1 with 0 fake
# Event 429 : Clutered PHS candidate in window = 1 with 0 fake
# Event 430 : Clutered PHS candidate in window = 1 with 0 fake
# Event 431 : Clutered PHS candidate in window = 2 with 1 fake
# Event 432 : Clutered PHS candidate in window = 1 with 0 fake
# Event 433 : Clutered PHS candidate in window = 1 with 0 fake
# Event 434 : Clutered PHS candidate in window = 1 with 0 fake
# Event 435 : Clutered PHS candidate in window = 1 with 0 fake
# Event 436 : Clutered PHS candidate in window = 1 with 0 fake
# Event 437 : Clutered PHS candidate in window = 1 with 0 fake
# Event 438 : Clutered PHS candidate in window = 1 with 0 fake
# Event 439 : Clutered PHS candidate in window = 1 with 0 fake
# Event 440 : Clutered PHS candidate in window = 1 with 0 fake
# Event 441 : Clutered PHS candidate in window = 1 with 0 fake
# Event 442 : Clutered PHS candidate in window = 1 with 0 fake
# Event 443 : Clutered PHS candidate in window = 1 with 0 fake
# Event 444 : Clutered PHS candidate in window = 1 with 0 fake
# Event 445 : Clutered PHS candidate in window = 1 with 0 fake
# Event 446 : Clutered PHS candidate in window = 1 with 0 fake
# Event 447 : Clutered PHS candidate in window = 1 with 0 fake
# Event 448 : Clutered PHS candidate in window = 1 with 0 fake
# Event 449 : Clutered PHS candidate in window = 2 with 1 fake
# Event 450 : Clutered PHS candidate in window = 1 with 0 fake
# Event 451 : Clutered PHS candidate in window = 1 with 0 fake
# Event 452 : Clutered PHS candidate in window = 1 with 0 fake
# Event 453 : Clutered PHS candidate in window = 1 with 0 fake
# Event 454 : Clutered PHS candidate in window = 1 with 0 fake
# Event 455 : Clutered PHS candidate in window = 1 with 0 fake
# Event 456 : Clutered PHS candidate in window = 1 with 0 fake
# Event 457 : Clutered PHS candidate in window = 2 with 1 fake
# Event 458 : Clutered PHS candidate in window = 1 with 0 fake
# Event 459 : Clutered PHS candidate in window = 1 with 0 fake
# Event 460 : Clutered PHS candidate in window = 1 with 0 fake
# Event 461 : Clutered PHS candidate in window = 1 with 0 fake
# Event 462 : Clutered PHS candidate in window = 1 with 0 fake
# Event 463 : Clutered PHS candidate in window = 1 with 0 fake
# Event 464 : Clutered PHS candidate in window = 1 with 0 fake
# Event 465 : Clutered PHS candidate in window = 1 with 0 fake
# Event 466 : Clutered PHS candidate in window = 1 with 0 fake
# Event 467 : Clutered PHS candidate in window = 2 with 1 fake
# Event 468 : Clutered PHS candidate in window = 1 with 0 fake
# Event 469 : Clutered PHS candidate in window = 1 with 0 fake
# Event 470 : Clutered PHS candidate in window = 1 with 0 fake
# Event 471 : Clutered PHS candidate in window = 1 with 0 fake
# Event 472 : Clutered PHS candidate in window = 1 with 0 fake
# Event 473 : Clutered PHS candidate in window = 1 with 0 fake
# Event 474 : Clutered PHS candidate in window = 1 with 0 fake
# Event 475 : Clutered PHS candidate in window = 1 with 0 fake
# Event 476 : Clutered PHS candidate in window = 1 with 0 fake
# Event 477 : Clutered PHS candidate in window = 1 with 0 fake
# Event 478 : Clutered PHS candidate in window = 1 with 0 fake
# Event 479 : Clutered PHS candidate in window = 1 with 0 fake
# Event 480 : Clutered PHS candidate in window = 1 with 0 fake
# Event 481 : Clutered PHS candidate in window = 1 with 0 fake
# Event 482 : Clutered PHS candidate in window = 1 with 0 fake
# Event 483 : Clutered PHS candidate in window = 1 with 0 fake
# Event 484 : Clutered PHS candidate in window = 1 with 0 fake
# Event 485 : Clutered PHS candidate in window = 1 with 0 fake
# Event 486 : Clutered PHS candidate in window = 1 with 0 fake
# Event 487 : Clutered PHS candidate in window = 1 with 0 fake
# Event 488 : Clutered PHS candidate in window = 1 with 0 fake
# Event 489 : Clutered PHS candidate in window = 1 with 0 fake
# Event 490 : Clutered PHS candidate in window = 1 with 0 fake
# Event 491 : Clutered PHS candidate in window = 1 with 0 fake
# Event 492 : Clutered PHS candidate in window = 1 with 0 fake
# Event 493 : Clutered PHS candidate in window = 1 with 0 fake
# Event 494 : Clutered PHS candidate in window = 1 with 0 fake
# Event 495 : Clutered PHS candidate in window = 1 with 0 fake
# Event 496 : Clutered PHS candidate in window = 1 with 0 fake
# Event 497 : Clutered PHS candidate in window = 1 with 0 fake
# Event 498 : Clutered PHS candidate in window = 1 with 0 fake
# Event 499 : Clutered PHS candidate in window = 1 with 0 fake
# Event 500 : Clutered PHS candidate in window = 1 with 0 fake

# %%
true_sigcap/(nval*500)*100
# Out:
# 99.4

# %%
fake_bkgcap/500*100
# Out:
# 6.6000000000000005

# %%
evnt_list = bkgpSig_true[466]

sig_only2 = np.zeros((720,720))
for ii in range(len(evnt_list)):
    sig_only2 += sig_only[evnt_list[ii]]

plt.imshow(sig_only2)
plt.savefig(f"./diff_stepsize/sample_true_g{gval}_n{nval}.pdf",bbox_inches='tight')

# %%
plt.imshow(clean_sig[466])
plt.savefig(f"./diff_stepsize/sample_pred_g{gval}_n{nval}.pdf",bbox_inches='tight')

# %%
plt.imshow(cleaned_sigs[466]>0)
plt.savefig(f"./diff_stepsize/sample_pred_g{gval}_n{nval}_cleaned.pdf",bbox_inches='tight')

# %%
plt.imshow(cleaned_bkgs[466])
#plt.savefig(f"./diff_stepsize/sample_pred_bkg_cleaned.pdf",bbox_inches='tight')

# %%
def find_nth_smallest(a, n):
    return np.partition(a, n-1)[n-1]
